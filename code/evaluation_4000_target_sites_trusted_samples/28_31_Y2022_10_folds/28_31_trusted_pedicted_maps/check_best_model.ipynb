# %%
import pandas as pd
import os

# %% [markdown]
# ### Check top transfer methods & 400,000 train form scratch

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/567_transfer_plot"
results_file = "temporal_mean.csv"
results = os.path.join(results_folder,results_file)
results
# Out:
# '/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/567_transfer_plot/temporal_mean.csv'

# %%
# Direct
data = pd.read_csv(results)
filtered = data[(data['Transfer Strategy']=='Direct')&(data['Target Site']=='Site B Previous Year')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best preprocessing: 7days_ln
# The best Model: transformer
# Out:
#     index Preprocessing        Model           Target Site  Test Size  \
# 10     31      7days_ln  transformer  Site B Previous Year     4000.0
# 32     97  7days_ln_whi  transformer  Site B Previous Year     4000.0
# 6      19      7days_ln       bi-rnn  Site B Previous Year     4000.0
#
#     Validation Size  Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  \
# 10              0.0          0.928594          0.910282          0.938761
# 32              0.0          0.926250          0.922619          0.927798
# 6               0.0          0.914594          0.914735          0.920119
#
#     Class 2 Accuracy    Recall  Precision     Kappa  F1 Score  \
# 10          0.939279  0.929674   0.926530  0.892408  0.928594
# 32          0.929245  0.926528   0.925358  0.889001  0.926250
# 6           0.906806  0.914040   0.912126  0.871209  0.914594
#
#    Transfer Strategy Train Site
# 10            Direct        NaN
# 32            Direct        NaN
# 6             Direct        NaN

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/0_source_domain_2022_table"
results_file = "28_31_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data.copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best preprocessing: 7days_ln
# The best Model: transformer
# Out:
#      index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 161    161  7days_ln_whi  transformer      320000      40000            40000
# 192    192      7days_ln  transformer      320000      40000            40000
# 93      93      7days_ln  transformer      320000      40000            40000
#
#      Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 161           0.95260          0.961664          0.965394          0.924675
# 192           0.95240          0.959766          0.969397          0.921878
# 93            0.95195          0.963219          0.965482          0.920507
#
#        Recall  Precision     Kappa  F1 Score   Train Time
# 161  0.950578   0.951307  0.928406   0.95260  1104.443243
# 192  0.950347   0.951178  0.928111   0.95240  1111.878059
# 93   0.949736   0.951205  0.927397   0.95195  1113.745173

# %% [markdown]
# ### Direct: best fold for site B

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/5_direct_transfer_results"
results_file = "temporal_direct_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Target Site']=='Site B Previous Year')&(data['Preprocessing']=='7days_ln')&(data['Model']=='transformer')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 3th fold
# Out:
#    index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 3    762      7days_ln  transformer           0       4000                0
# 2    729      7days_ln  transformer           0       4000                0
# 5    828      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 3           0.93075          0.913978          0.940202          0.941281
# 2           0.93050          0.913978          0.944524          0.935053
# 5           0.92975          0.913978          0.938040          0.940391
#
#      Recall  Precision     Kappa  F1 Score  Train Time           Target Site
# 3  0.931820   0.928772  0.895642   0.93075           0  Site B Previous Year
# 2  0.931185   0.928464  0.895242   0.93050           0  Site B Previous Year
# 5  0.930803   0.927629  0.894148   0.92975           0  Site B Previous Year

# %% [markdown]
# ### 400, 000 train form scratch: best fold for site B

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/0_source_domain_2022_table"
results_file = "28_31_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Preprocessing']=='7days_ln_whi')&(data['Model']=='transformer')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 4th fold
# Out:
#    index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 4    161  7days_ln_whi  transformer      320000      40000            40000
# 6    227  7days_ln_whi  transformer      320000      40000            40000
# 7    260  7days_ln_whi  transformer      320000      40000            40000
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 4          0.952600          0.961664          0.965394          0.924675
# 6          0.950725          0.963078          0.961168          0.921885
# 7          0.950575          0.957973          0.962271          0.926784
#
#      Recall  Precision     Kappa  F1 Score   Train Time
# 4  0.950578   0.951307  0.928406  0.952600  1104.443243
# 6  0.948710   0.949574  0.925606  0.950725  1104.786602
# 7  0.949009   0.949234  0.925423  0.950575  1105.069730
