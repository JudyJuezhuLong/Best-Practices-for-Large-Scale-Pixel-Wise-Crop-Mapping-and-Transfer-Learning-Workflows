# %%
import pandas as pd
import os

# %% [markdown]
# ### Check top transfer methods & 400,000 train form scratch

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/567_transfer_plot"
results_file = "spatial_mean.csv"
results = os.path.join(results_folder,results_file)
results
# Out:
# '/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/567_transfer_plot/spatial_mean.csv'

# %%
# Direct
data = pd.read_csv(results)
filtered = data[(data['Transfer Strategy']=='Direct')&(data['Target Site']=='Site A to B')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best preprocessing: 7days_ln
# The best Model: transformer
# Out:
#     index        Preprocessing        Model  Target Site  Test Size  \
# 10     50             7days_ln  transformer  Site A to B     4000.0
# 21    105  7days_ln_pheno_peak  transformer  Site A to B     4000.0
# 32    160         7days_ln_whi  transformer  Site A to B     4000.0
#
#     Validation Size  Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  \
# 10              0.0          0.910375          0.868407          0.944081
# 21              0.0          0.902906          0.842037          0.936572
# 32              0.0          0.902500          0.837451          0.950874
#
#     Class 2 Accuracy    Recall  Precision     Kappa  F1 Score  \
# 10          0.922421  0.911359   0.910007  0.865070  0.910375
# 21          0.937937  0.905495   0.903081  0.854080  0.902906
# 32          0.933491  0.907023   0.901057  0.852959  0.902500
#
#    Transfer Strategy Train Site
# 10            Direct        NaN
# 21            Direct        NaN
# 32            Direct        NaN

# %%
# DANN
data = pd.read_csv(results)
filtered = data[(data['Transfer Strategy']=='DANN')&(data['Target Site']=='Site A to B')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best preprocessing: 7days_ln_whi
# The best Model: transformer
# Out:
#     index Preprocessing        Model  Target Site  Test Size  Validation Size  \
# 29    400  7days_ln_whi  transformer  Site A to B     4000.0              0.0
# 21    360  7days_ln_whi    atbi-lstm  Site A to B     4000.0              0.0
# 25    380  7days_ln_whi       bi-rnn  Site A to B     4000.0              0.0
#
#     Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 29           0.91225          0.901821          0.926534          0.908491
# 21           0.91225          0.910273          0.922254          0.901887
# 25           0.90875          0.873212          0.928673          0.933962
#
#       Recall  Precision     Kappa  F1 Score Transfer Strategy Train Site
# 29  0.912282   0.908730  0.867164   0.91225              DANN        NaN
# 21  0.911471   0.909881  0.866986   0.91225              DANN        NaN
# 25  0.911949   0.905084  0.862267   0.90875              DANN        NaN

# %%
"""
# Fine Tuning
data = pd.read_csv(results)
filtered = data[(data['Transfer Strategy']=='Fine Tuning')&(data['Target Site']=='Site A to B')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best preprocessing: 7days_ln_pheno_peak
# The best Model: bi-rnn
"""
# Out:
#     index        Preprocessing        Model  Target Site  Test Size  \
# 15    210  7days_ln_pheno_peak       bi-rnn  Site A to B     4000.0
# 29    252         7days_ln_whi  transformer  Site A to B     4000.0
# 18    219  7days_ln_pheno_peak          rnn  Site A to B     4000.0
#
#     Validation Size  Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  \
# 15              0.0          0.897969          0.844899          0.941873
# 29              0.0          0.892063          0.817620          0.961484
# 18              0.0          0.880281          0.790510          0.947527
#
#     Class 2 Accuracy    Recall  Precision     Kappa  F1 Score  \
# 15          0.912150  0.899192   0.898611  0.846454  0.897969
# 29          0.914623  0.896074   0.897196  0.836743  0.892063
# 18          0.909747  0.882740   0.883342  0.820008  0.880281
#
#    Transfer Strategy Train Site
# 15       Fine Tuning        NaN
# 29       Fine Tuning        NaN
# 18       Fine Tuning        NaN

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/0_source_domain_table"
results_file = "28_31_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data.copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best preprocessing: 7days_ln
# The best Model: transformer
# Out:
#      index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 201    201      7days_ln  transformer      320000      40000            40000
# 354    354      7days_ln  transformer      320000      40000            40000
# 48      48      7days_ln  transformer      320000      40000            40000
#
#      Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 201          0.951675          0.955650          0.964146          0.930315
# 354          0.951200          0.958412          0.963645          0.926144
# 48           0.950600          0.959761          0.964187          0.921741
#
#        Recall  Precision     Kappa  F1 Score   Train Time
# 201  0.950037   0.949730  0.926991  0.951675  1101.118957
# 354  0.949401   0.949531  0.926307  0.951200  1077.996156
# 48   0.948563   0.949342  0.925421  0.950600  1077.373081

# %% [markdown]
# ### Direct: best fold for site B

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/5_direct_transfer_results"
results_file = "spatial_direct_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Target Site']=='Site A to B')&(data['Preprocessing']=='7days_ln')&(data['Model']=='transformer')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 9th fold
# Out:
#    index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 9    628      7days_ln  transformer           0       4000                0
# 6    529      7days_ln  transformer           0       4000                0
# 8    595      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 9           0.92075          0.895906          0.939223          0.929196
# 6           0.91450          0.879944          0.946290          0.918706
# 8           0.91400          0.873005          0.949117          0.922203
#
#      Recall  Precision     Kappa  F1 Score  Train Time  Target Site
# 9  0.921441   0.919653  0.880664   0.92075           0  Site A to B
# 6  0.914980   0.913646  0.871232   0.91450           0  Site A to B
# 8  0.914775   0.913465  0.870516   0.91400           0  Site A to B

# %% [markdown]
# # Fine Tuning: best fold for site B

# %%
"""
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/6_fine_tuning_results"
results_file = "spatial_fine_tuning_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Target Site']=='Site A to B')&(data['Preprocessing']=='7days_ln_pheno_peak')&(data['Model']=='bi-rnn')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 9th fold
"""
# Out:
#    index        Preprocessing   Model  Train Size  Test Size  Validation Size  \
# 9    289  7days_ln_pheno_peak  bi-rnn           0       4000                0
# 1     49  7days_ln_pheno_peak  bi-rnn           0       4000                0
# 4    139  7days_ln_pheno_peak  bi-rnn           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 9           0.90875          0.870923          0.950530          0.904720
# 1           0.90700          0.866065          0.944170          0.912587
# 4           0.90300          0.855656          0.942049          0.914336
#
#      Recall  Precision     Kappa  F1 Score  Train Time  Target Site
# 9  0.908724   0.909467  0.862497   0.90875           0  Site A to B
# 1  0.907607   0.906362  0.860017   0.90700           0  Site A to B
# 4  0.904014   0.902755  0.854024   0.90300           0  Site A to B

# %% [markdown]
# ### 400, 000 train form scratch: best fold for site B

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/0_source_domain_table"
results_file = "28_31_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Preprocessing']=='7days_ln')&(data['Model']=='transformer')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 3th fold
# Out:
#    index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 3    201      7days_ln  transformer      320000      40000            40000
# 6    354      7days_ln  transformer      320000      40000            40000
# 0     48      7days_ln  transformer      320000      40000            40000
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 3          0.951675          0.955650          0.964146          0.930315
# 6          0.951200          0.958412          0.963645          0.926144
# 0          0.950600          0.959761          0.964187          0.921741
#
#      Recall  Precision     Kappa  F1 Score   Train Time
# 3  0.950037   0.949730  0.926991  0.951675  1101.118957
# 6  0.949401   0.949531  0.926307  0.951200  1077.996156
# 0  0.948563   0.949342  0.925421  0.950600  1077.373081
