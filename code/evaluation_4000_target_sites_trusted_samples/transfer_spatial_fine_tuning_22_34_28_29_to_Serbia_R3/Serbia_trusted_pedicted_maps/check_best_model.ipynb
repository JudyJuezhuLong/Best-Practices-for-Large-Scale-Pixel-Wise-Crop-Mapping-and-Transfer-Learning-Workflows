# %%
import pandas as pd
import os

# %% [markdown]
# ### Direct Should Match Fine Tuning: best fold for site E

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/5_direct_transfer_results_two_spatial_sites_AD_to_E/clean_df"
results_file = "28_29_22_34_to_Serbia_spatial_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Preprocessing']=='7days_ln')&(data['Model']=='transformer')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 7th fold
# Out:
#    index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 7     23      7days_ln  transformer           0       4000                0
# 6     20      7days_ln  transformer           0       4000                0
# 2      8      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 7           0.75775          0.556898          0.520885          0.871538
# 6           0.75400          0.534743          0.525799          0.873462
# 2           0.75050          0.483384          0.491400          0.893077
#
#      Recall  Precision     Kappa  F1 Score  Train Time
# 7  0.649774   0.692491  0.501082   0.75775           0
# 6  0.644668   0.692762  0.490214   0.75400           0
# 2  0.622620   0.692207  0.469250   0.75050           0

# %% [markdown]
# # Fine Tuning: best fold for site E

# %%
# R1
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/6_fine_tuning_R3_results/clean_df"
results_file = "22_34_28_29_to_Serbia_R1_spatial_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
data.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 4th fold
# Out:
#   Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 4      7days_ln  transformer           0       4000                0
# 6      7days_ln  transformer           0       4000                0
# 9      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 4           0.76225          0.647533          0.481572          0.850000
# 6           0.75550          0.622356          0.454545          0.853462
# 9           0.75350          0.679758          0.385749          0.839231
#
#      Recall  Precision     Kappa  F1 Score  Train Time
# 4  0.659702   0.709352  0.523412   0.76225           0
# 6  0.643454   0.703706  0.504511   0.75550           0
# 9  0.634913   0.719115  0.507335   0.75350           0

# %%
# R2
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/6_fine_tuning_R3_results/clean_df"
results_file = "22_34_28_29_to_Serbia_R2_spatial_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
data.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 3th fold
# Out:
#   Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 3      7days_ln  transformer           0       4000                0
# 6      7days_ln  transformer           0       4000                0
# 5      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 3           0.62900          0.648540          0.680590          0.613462
# 6           0.59875          0.715005          0.670762          0.543077
# 5           0.57450          0.735146          0.651106          0.501154
#
#      Recall  Precision     Kappa  F1 Score  Train Time
# 3  0.647530   0.561799  0.381411   0.62900           0
# 6  0.642948   0.558146  0.348762   0.59875           0
# 5  0.629135   0.552873  0.321742   0.57450           0

# %%
# R3
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/6_fine_tuning_R3_results/clean_df"
results_file = "22_34_28_29_to_Serbia_R3_spatial_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
data.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 6th fold
# Out:
#   Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 6      7days_ln  transformer           0       4000                0
# 9      7days_ln  transformer           0       4000                0
# 4      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 6           0.75575          0.685801          0.584767          0.809231
# 9           0.75575          0.550856          0.601966          0.858077
# 4           0.75500          0.563948          0.538084          0.861923
#
#      Recall  Precision     Kappa  F1 Score  Train Time
# 6  0.693266   0.692394  0.530952   0.75575           0
# 9  0.670300   0.676606  0.508299   0.75575           0
# 4  0.654651   0.681591  0.501728   0.75500           0

# %%
# R4
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/6_fine_tuning_R3_results/clean_df"
results_file = "22_34_28_29_to_Serbia_R4_spatial_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
data.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 9th fold
# Out:
#   Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 9      7days_ln  transformer           0       4000                0
# 5      7days_ln  transformer           0       4000                0
# 4      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 9           0.74550          0.603223          0.628993          0.818077
# 5           0.74425          0.589124          0.616708          0.823462
# 4           0.74000          0.615307          0.565111          0.815000
#
#      Recall  Precision     Kappa  F1 Score  Train Time
# 9  0.683431   0.665370  0.506639   0.74550           0
# 5  0.676431   0.660563  0.501569   0.74425           0
# 4  0.665139   0.672619  0.491478   0.74000           0

# %% [markdown]
# ### 8, 000 train form scratch: best fold for site E

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/1_target_domain_table/clean_df"
results_file = "Serbia_spatial_train_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Preprocessing']=='7days_ln')&(data['Model']=='RF')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of RF is the 3th fold
# Out:
#    index Preprocessing Model  Train Size  Test Size  Validation Size  \
# 3     86      7days_ln    RF        8000       4000             1000
# 8    196      7days_ln    RF        8000       4000             1000
# 7    174      7days_ln    RF        8000       4000             1000
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 3           0.83475          0.677744          0.628993          0.926923
# 8           0.83400          0.687815          0.619165          0.923462
# 7           0.83275          0.682779          0.651106          0.918462
#
#      Recall  Precision     Kappa  F1 Score  Train Time
# 3  0.744553   0.802537  0.657034   0.83475    1.573521
# 8  0.743480   0.803109  0.656103   0.83400    1.629350
# 7  0.750782   0.795905  0.656097   0.83275    1.584493
