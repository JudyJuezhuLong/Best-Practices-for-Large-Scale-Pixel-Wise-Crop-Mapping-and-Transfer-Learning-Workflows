# %%
import pandas as pd
import os

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/0_source_domain_table"
results_file = "28_29_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
results
# Out:
# '/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/0_source_domain_table/28_29_10_folds_metrics.csv'

# %%
data = pd.read_csv(results)
filtered = data[(data['Preprocessing']=='7days_ln')&(data['Model']=='RF')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False)
# The best fold of RF is the 8th fold
# Out:
#    index Preprocessing Model  Train Size  Test Size  Validation Size  \
# 8    429      7days_ln    RF      320000      40000            40000
# 1     71      7days_ln    RF      320000      40000            40000
# 9    480      7days_ln    RF      320000      40000            40000
# 6    327      7days_ln    RF      320000      40000            40000
# 0     20      7days_ln    RF      320000      40000            40000
# 4    225      7days_ln    RF      320000      40000            40000
# 2    123      7days_ln    RF      320000      40000            40000
# 7    378      7days_ln    RF      320000      40000            40000
# 5    276      7days_ln    RF      320000      40000            40000
# 3    174      7days_ln    RF      320000      40000            40000
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 8          0.952775          0.945857          0.963689          0.948466
# ...

# %%
filtered = data[(data['Preprocessing']=='7days_ln')&(data['Model']=='transformer')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False)
# The best fold of RF is the 3th fold
# Out:
#    index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 3    179      7days_ln  transformer      320000      40000            40000
# 9    490      7days_ln  transformer      320000      40000            40000
# 0     23      7days_ln  transformer      320000      40000            40000
# 1     75      7days_ln  transformer      320000      40000            40000
# 8    438      7days_ln  transformer      320000      40000            40000
# 6    334      7days_ln  transformer      320000      40000            40000
# 7    386      7days_ln  transformer      320000      40000            40000
# 2    126      7days_ln  transformer      320000      40000            40000
# 4    230      7days_ln  transformer      320000      40000            40000
# 5    282      7days_ln  transformer      320000      40000            40000
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# ...
