# %%
import pandas as pd
import os

# %% [markdown]
# ### Check top transfer methods & 400,000 train form scratch

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/567_transfer_plot"
results_file = "spatial_mean.csv"
results = os.path.join(results_folder,results_file)
results
# Out:
# '/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/567_transfer_plot/spatial_mean.csv'

# %%
# Direct
data = pd.read_csv(results)
filtered = data[(data['Transfer Strategy']=='Direct')&(data['Target Site']=='Site A to E')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False)#.head(3)
# The best preprocessing: chose 7days_ln (, though it is the 3rd)
# The best Model: transformer
# Out:
#     index        Preprocessing        Model  Target Site  Test Size  \
# 32    162         7days_ln_whi  transformer  Site A to E     4000.0
# 5      27             7days_ln      bi-lstm  Site A to E     4000.0
# 10     52             7days_ln  transformer  Site A to E     4000.0
# 2      12             7days_ln    atbi-lstm  Site A to E     4000.0
# 7      37             7days_ln          gru  Site A to E     4000.0
# 6      32             7days_ln       bi-rnn  Site A to E     4000.0
# 3      17             7days_ln     atbi-rnn  Site A to E     4000.0
# 9      47             7days_ln          rnn  Site A to E     4000.0
# 4      22             7days_ln       bi-gru  Site A to E     4000.0
# 25    127         7days_ln_whi     atbi-rnn  Site A to E     4000.0
# 1       7             7days_ln     atbi-gru  Site A to E     4000.0
# 27    137         7days_ln_whi      bi-lstm  Site A to E     4000.0
# 26    132         7days_ln_whi       bi-gru  Site A to E     4000.0
# 29    147         7days_ln_whi          gru  Site A to E     4000.0
# 8      42             7days_ln         lstm  Site A to E     4000.0
# 28    142         7days_ln_whi       bi-rnn  Site A to E     4000.0
# 31    157         7days_ln_whi          rnn  Site A to E     4000.0
# 24    122         7days_ln_whi    atbi-lstm  Site A to E     4000.0
# 23    117         7days_ln_whi     atbi-gru  Site A to E     4000.0
# 30    152         7days_ln_whi         lstm  Site A to E     4000.0
# 17     87  7days_ln_pheno_peak       bi-rnn  Site A to E     4000.0
# 14     72  7days_ln_pheno_peak     atbi-rnn  Site A to E     4000.0
# 15     77  7days_ln_pheno_peak       bi-gru  Site A to E     4000.0
# 21    107  7days_ln_pheno_peak  transformer  Site A to E     4000.0
# 12     62  7days_ln_pheno_peak     atbi-gru  Site A to E     4000.0
# 20    102  7days_ln_pheno_peak          rnn  Site A to E     4000.0
# 22    112         7days_ln_whi           RF  Site A to E     4000.0
# 0       2             7days_ln           RF  Site A to E     4000.0
# 18     92  7days_ln_pheno_peak          gru  Site A to E     4000.0
# 13     67  7days_ln_pheno_peak    atbi-lstm  Site A to E     4000.0
# 16     82  7days_ln_pheno_peak      bi-lstm  Site A to E     4000.0
# 19     97  7days_ln_pheno_peak         lstm  Site A to E     4000.0
# 11     57  7days_ln_pheno_peak           RF  Site A to E     4000.0
#
#     Validation Size  Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy
# 13          0.793942  0.575650   0.589234  0.352154  0.677281
# 16          0.792404  0.569579   0.584975  0.341855  0.673375
# 19          0.799375  0.570989   0.579644  0.337611  0.672500
# 11          0.787788  0.536860   0.552767  0.278809  0.649000
#
#    Transfer Strategy Train Site
# 32            Direct        NaN
# 5             Direct        NaN
# 10            Direct        NaN
# 2             Direct        NaN
# 7             Direct        NaN
# 6             Direct        NaN
# 3             Direct        NaN
# 9             Direct        NaN
# 4             Direct        NaN
# 25            Direct        NaN
# 1             Direct        NaN
# 27            Direct        NaN
# 26            Direct        NaN
# 29            Direct        NaN
# 8             Direct        NaN
# 28            Direct        NaN
# 31            Direct        NaN
# 24            Direct        NaN
# 23            Direct        NaN
# 30            Direct        NaN
# 17            Direct        NaN
# 14            Direct        NaN
# 15            Direct        NaN
# 21            Direct        NaN
# 12            Direct        NaN
# 20            Direct        NaN
# 22            Direct        NaN
# 0             Direct        NaN
# 18            Direct        NaN
# 13            Direct        NaN
# 16            Direct        NaN
# 19            Direct        NaN
# 11            Direct        NaN

# %%
# DANN
data = pd.read_csv(results)
filtered = data[(data['Transfer Strategy']=='DANN')&(data['Target Site']=='Site A to E')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False)#.head(3)
# The best preprocessing: 7days_ln_whi
# The best Model: transformer
# Out:
#     index        Preprocessing        Model  Target Site  Test Size  \
# 21    362         7days_ln_whi    atbi-lstm  Site A to E     4000.0
# 27    392         7days_ln_whi         lstm  Site A to E     4000.0
# 1     262             7days_ln    atbi-lstm  Site A to E     4000.0
# 25    382         7days_ln_whi       bi-rnn  Site A to E     4000.0
# 2     267             7days_ln     atbi-rnn  Site A to E     4000.0
# 29    402         7days_ln_whi  transformer  Site A to E     4000.0
# 22    367         7days_ln_whi     atbi-rnn  Site A to E     4000.0
# 11    312  7days_ln_pheno_peak    atbi-lstm  Site A to E     4000.0
# 16    337  7days_ln_pheno_peak          gru  Site A to E     4000.0
# 8     297             7days_ln          rnn  Site A to E     4000.0
# 15    332  7days_ln_pheno_peak       bi-rnn  Site A to E     4000.0
# 6     287             7days_ln          gru  Site A to E     4000.0
# 18    347  7days_ln_pheno_peak          rnn  Site A to E     4000.0
# 26    387         7days_ln_whi          gru  Site A to E     4000.0
# 0     257             7days_ln     atbi-gru  Site A to E     4000.0
# 4     277             7days_ln      bi-lstm  Site A to E     4000.0
# 19    352  7days_ln_pheno_peak  transformer  Site A to E     4000.0
# 10    307  7days_ln_pheno_peak     atbi-gru  Site A to E     4000.0
# 17    342  7days_ln_pheno_peak         lstm  Site A to E     4000.0
# 24    377         7days_ln_whi      bi-lstm  Site A to E     4000.0
# 23    372         7days_ln_whi       bi-gru  Site A to E     4000.0
# 12    317  7days_ln_pheno_peak     atbi-rnn  Site A to E     4000.0
# 3     272             7days_ln       bi-gru  Site A to E     4000.0
# 5     282             7days_ln       bi-rnn  Site A to E     4000.0
# 7     292             7days_ln         lstm  Site A to E     4000.0
# 20    357         7days_ln_whi     atbi-gru  Site A to E     4000.0
# 13    322  7days_ln_pheno_peak       bi-gru  Site A to E     4000.0
# 28    397         7days_ln_whi          rnn  Site A to E     4000.0
# 14    327  7days_ln_pheno_peak      bi-lstm  Site A to E     4000.0
# 9     302             7days_ln  transformer  Site A to E     4000.0
#
#     Validation Size  Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy
# 3           0.714231  0.569796   0.519406  0.297783   0.62275
# 5           0.690769  0.583069   0.537478  0.309368   0.61925
# 7           0.669615  0.588855   0.527087  0.315544   0.61650
# 20          0.629449  0.606106   0.530500  0.318618   0.61375
# 13          0.650769  0.602055   0.531865  0.318306   0.61300
# 28          0.691270  0.559077   0.505489  0.258996   0.61200
# 14          0.624615  0.589913   0.521998  0.293277   0.59525
# 9           0.618846  0.574698   0.520383  0.295307   0.58700
#
#    Transfer Strategy Train Site
# 21              DANN        NaN
# 27              DANN        NaN
# 1               DANN        NaN
# 25              DANN        NaN
# 2               DANN        NaN
# 29              DANN        NaN
# 22              DANN        NaN
# 11              DANN        NaN
# 16              DANN        NaN
# 8               DANN        NaN
# 15              DANN        NaN
# 6               DANN        NaN
# 18              DANN        NaN
# 26              DANN        NaN
# 0               DANN        NaN
# 4               DANN        NaN
# 19              DANN        NaN
# 10              DANN        NaN
# 17              DANN        NaN
# 24              DANN        NaN
# 23              DANN        NaN
# 12              DANN        NaN
# 3               DANN        NaN
# 5               DANN        NaN
# 7               DANN        NaN
# 20              DANN        NaN
# 13              DANN        NaN
# 28              DANN        NaN
# 14              DANN        NaN
# 9               DANN        NaN

# %%
# Fine Tuning
data = pd.read_csv(results)
filtered = data[(data['Transfer Strategy']=='Fine Tuning')&(data['Target Site']=='Site A to E')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False)#.head(6)
# The best preprocessing: 7days_ln
# The best Model: transformer
# Out:
#     index        Preprocessing        Model  Target Site  Test Size  \
# 8     191             7days_ln          rnn  Site A to E     4000.0
# 9     194             7days_ln  transformer  Site A to E     4000.0
# 5     182             7days_ln       bi-rnn  Site A to E     4000.0
# 1     170             7days_ln    atbi-lstm  Site A to E     4000.0
# 4     179             7days_ln      bi-lstm  Site A to E     4000.0
# 29    254         7days_ln_whi  transformer  Site A to E     4000.0
# 0     167             7days_ln     atbi-gru  Site A to E     4000.0
# 6     185             7days_ln          gru  Site A to E     4000.0
# 24    239         7days_ln_whi      bi-lstm  Site A to E     4000.0
# 7     188             7days_ln         lstm  Site A to E     4000.0
# 3     176             7days_ln       bi-gru  Site A to E     4000.0
# 2     173             7days_ln     atbi-rnn  Site A to E     4000.0
# 28    251         7days_ln_whi          rnn  Site A to E     4000.0
# 19    224  7days_ln_pheno_peak  transformer  Site A to E     4000.0
# 23    236         7days_ln_whi       bi-gru  Site A to E     4000.0
# 22    233         7days_ln_whi     atbi-rnn  Site A to E     4000.0
# 18    221  7days_ln_pheno_peak          rnn  Site A to E     4000.0
# 21    230         7days_ln_whi    atbi-lstm  Site A to E     4000.0
# 25    242         7days_ln_whi       bi-rnn  Site A to E     4000.0
# 15    212  7days_ln_pheno_peak       bi-rnn  Site A to E     4000.0
# 26    245         7days_ln_whi          gru  Site A to E     4000.0
# 20    227         7days_ln_whi     atbi-gru  Site A to E     4000.0
# 27    248         7days_ln_whi         lstm  Site A to E     4000.0
# 12    203  7days_ln_pheno_peak     atbi-rnn  Site A to E     4000.0
# 25          0.850337  0.563173   0.693798  0.431366  0.725687
# 15          0.920625  0.520553   0.685253  0.370522  0.724219
# 26          0.846250  0.592768   0.665347  0.434925  0.724125
# 20          0.903990  0.540307   0.657140  0.379666  0.720469
# 27          0.920000  0.535840   0.657864  0.364454  0.720250
# 12          0.865288  0.588044   0.630097  0.394754  0.713812
# 13          0.857019  0.584139   0.632061  0.391915  0.711656
# 10          0.854183  0.578465   0.616600  0.376853  0.704500
# 11          0.843510  0.568877   0.616592  0.371911  0.700719
# 14          0.826250  0.566861   0.600811  0.359536  0.690312
# 17          0.824375  0.565537   0.598533  0.350615  0.686406
# 16          0.807788  0.583576   0.596660  0.358422  0.683875
#
#    Transfer Strategy Train Site
# 8        Fine Tuning        NaN
# 9        Fine Tuning        NaN
# 5        Fine Tuning        NaN
# 1        Fine Tuning        NaN
# 4        Fine Tuning        NaN
# 29       Fine Tuning        NaN
# 0        Fine Tuning        NaN
# 6        Fine Tuning        NaN
# 24       Fine Tuning        NaN
# 7        Fine Tuning        NaN
# 3        Fine Tuning        NaN
# 2        Fine Tuning        NaN
# 28       Fine Tuning        NaN
# 19       Fine Tuning        NaN
# 23       Fine Tuning        NaN
# 22       Fine Tuning        NaN
# 18       Fine Tuning        NaN
# 21       Fine Tuning        NaN
# 25       Fine Tuning        NaN
# 15       Fine Tuning        NaN
# 26       Fine Tuning        NaN
# 20       Fine Tuning        NaN
# 27       Fine Tuning        NaN
# 12       Fine Tuning        NaN
# 13       Fine Tuning        NaN
# 10       Fine Tuning        NaN
# 11       Fine Tuning        NaN
# 14       Fine Tuning        NaN
# 17       Fine Tuning        NaN
# 16       Fine Tuning        NaN

# %%
# results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/0_source_domain_table"
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/1_target_domain_table/clean_df"
# results_file = "28_31_10_folds_metrics.csv"
results_file = "Serbia_spatial_train_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results).groupby(['Preprocessing', 'Model']).mean()
filtered = data.copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best preprocessing: 7days_ln
# The best Model: RF
# Out:
#           Preprocessing Model  Train Size  Test Size  Validation Size  \
# 0              7days_ln    RF      8000.0     4000.0           1000.0
# 22         7days_ln_whi    RF      8000.0     4000.0           1000.0
# 11  7days_ln_pheno_peak    RF      8000.0     4000.0           1000.0
#
#     Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 0           0.831667          0.677185          0.630085          0.922222
# 22          0.831139          0.678080          0.638275          0.919786
# 11          0.828917          0.659953          0.607699          0.928077
#
#       Recall  Precision     Kappa  F1 Score  Train Time
# 0   0.743164   0.798643  0.651591  0.831667    1.645498
# 22  0.745380   0.797847  0.651246  0.831139    1.659133
# 11  0.731910   0.801645  0.642248  0.828917    1.644784

# %% [markdown]
# ### Direct Should Match Fine Tuning: best fold for site B

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/5_direct_transfer_results"
results_file = "spatial_direct_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Target Site']=='Site A to E')&(data['Preprocessing']=='7days_ln')&(data['Model']=='transformer')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 9th fold
# Out:
#    index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 9    970      7days_ln  transformer           0       4000                0
# 0    772      7days_ln  transformer           0       4000                0
# 8    948      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 9           0.74775          0.466264          0.442260          0.903077
# 0           0.74550          0.430010          0.444717          0.913077
# 8           0.74550          0.449144          0.442260          0.906154
#
#      Recall  Precision     Kappa  F1 Score  Train Time  Target Site
# 9  0.603867   0.687718  0.455669   0.74775           0  Site A to E
# 0  0.595935   0.687985  0.442443   0.74550           0  Site A to E
# 8  0.599186   0.685337  0.447428   0.74550           0  Site A to E

# %% [markdown]
# # Fine Tuning: best fold for site B

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/6_fine_tuning_results"
results_file = "spatial_fine_tuning_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Target Site']=='Site A to E')&(data['Preprocessing']=='7days_ln')&(data['Model']=='transformer')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of transformer is the 4th fold
# Out:
#    index Preprocessing        Model  Train Size  Test Size  Validation Size  \
# 4    444      7days_ln  transformer           0       4000                0
# 5    474      7days_ln  transformer           0       4000                0
# 2    384      7days_ln  transformer           0       4000                0
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 4             0.761          0.549849          0.405405          0.897308
# 5             0.760          0.573011          0.417690          0.885000
# 2             0.759          0.608258          0.420147          0.869615
#
#      Recall  Precision     Kappa  F1 Score  Train Time  Target Site
# 4  0.617521   0.711418  0.494310     0.761           0  Site A to E
# 5  0.625234   0.715714  0.498204     0.760           0  Site A to E
# 2  0.632674   0.703017  0.505443     0.759           0  Site A to E

# %% [markdown]
# ### 8, 000 train form scratch: best fold for site B

# %%
results_folder = "/mnt/mridata/Anonymouslong/best_practice_pixel/visualization/1_target_domain_table/clean_df"
results_file = "Serbia_spatial_train_10_folds_metrics.csv"
results = os.path.join(results_folder,results_file)
data = pd.read_csv(results)
filtered = data[(data['Preprocessing']=='7days_ln')&(data['Model']=='RF')].copy()
filtered = filtered.reset_index()
filtered.sort_values('Overall Accuracy', ascending=False).head(3)
# The best fold of RF is the 3th fold
# Out:
#    index Preprocessing Model  Train Size  Test Size  Validation Size  \
# 3     86      7days_ln    RF        8000       4000             1000
# 8    196      7days_ln    RF        8000       4000             1000
# 7    174      7days_ln    RF        8000       4000             1000
#
#    Overall Accuracy  Class 0 Accuracy  Class 1 Accuracy  Class 2 Accuracy  \
# 3           0.83475          0.677744          0.628993          0.926923
# 8           0.83400          0.687815          0.619165          0.923462
# 7           0.83275          0.682779          0.651106          0.918462
#
#      Recall  Precision     Kappa  F1 Score  Train Time
# 3  0.744553   0.802537  0.657034   0.83475    1.573521
# 8  0.743480   0.803109  0.656103   0.83400    1.629350
# 7  0.750782   0.795905  0.656097   0.83275    1.584493
